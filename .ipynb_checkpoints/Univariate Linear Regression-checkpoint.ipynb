# %% [markdown]
# <h2 align="center">Linear Regression </h2>

# %% [markdown]
# Load the Data and Libraries
# ---

# %%
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
# %matplotlib inline

# %%
import numpy as np
import pandas as pd  
import seaborn as sns 
plt.rcParams['figure.figsize'] = (12, 8)

# %%
data = pd.read_csv('bike_sharing_data.txt')
n=data.Population.values.size
data.head(n)
# Out:
#     Population    Profit
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# ..         ...       ...
# 92      5.8707   7.20290
# 93      5.3054   1.98690
# 94      8.2934   0.14454
# 95     13.3940   9.05510
# 96      5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
# Population    97 non-null float64
# Profit        97 non-null float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %% [markdown]
# ### Task 3: Visualize the Data
# ---

# %%
ax=plt.scatter('Population','Profit',data=data)

# %% [markdown]
# Compute the Cost $J(\theta)$
# ---

# %% [markdown]
# The objective of linear regression is to minimize the cost function
#
# $$J(\theta) = \frac{1}{2m} \sum_{i=1}^m (h_\theta(x^{(i)}) - y^{(i)} )^2$$
#
# where $h_{\theta}(x)$ is the hypothesis and given by the linear model
#
# $$h_{\theta}(x) = \theta^Tx = \theta_0 + \theta_1x_1$$

# %%
def cost_func(x,y,theta):
    m=len(x)
    y_pred=x.dot(theta)
    error=(y_pred - y)**2
    return 1/(2*m)*np.sum(error)

# %%
m=data.Population.values.size
x=np.append(np.ones((m,1)),data.Population.values.reshape(m,1),axis=1)
y=data.Profit.values.reshape(m,1)
theta=np.zeros((2,1))
print(x,y,theta)
# Out:
# [[ 1.      6.1101]
#  [ 1.      5.5277]
#  [ 1.      8.5186]
#  [ 1.      7.0032]
#  [ 1.      5.8598]
#  [ 1.      8.3829]
#  [ 1.      7.4764]
#  [ 1.      8.5781]
#  [ 1.      6.4862]
#  [ 1.      5.0546]
#  [ 1.      5.7107]
#  [ 1.     14.164 ]
#  [ 1.      5.734 ]
#  [ 1.      8.4084]
#  [ 1.      5.6407]
#  [ 1.      5.3794]
#  [ 1.      6.3654]
#  [ 1.      5.1301]
#  [ 1.      6.4296]
#  [ 1.      7.0708]
#  [ 1.      6.1891]
#  [ 1.     20.27  ]
#  [ 1.      5.4901]
#  [ 1.      6.3261]
#  [ 1.      5.5649]
#  [ 1.     18.945 ]
#  [ 1.     12.828 ]
#  [ 1.     10.957 ]
#  [ 1.     13.176 ]
#  [ 1.     22.203 ]
#  [ 1.      5.2524]
#  [ 1.      6.5894]
#  [ 1.      9.2482]
#  [ 1.      5.8918]
#  [ 1.      8.2111]
#  [ 1.      7.9334]
#  [ 1.      8.0959]
#  [ 1.      5.6063]
#  [ 1.     12.836 ]
#  [ 1.      6.3534]
#  [ 1.      5.4069]
#  [ 1.      6.8825]
#  [ 1.     11.708 ]
#  [ 1.      5.7737]
#  [ 1.      7.8247]
#  [ 1.      7.0931]
#  [ 1.      5.0702]
#  [ 1.      5.8014]
#  [ 1.     11.7   ]
#  [ 1.      5.5416]
#  [ 1.      7.5402]
#  [ 1.      5.3077]
#  [ 1.      7.4239]
#  [ 1.      7.6031]
#  [ 1.      6.3328]
#  [ 1.      6.3589]
#  [ 1.      6.2742]
#  [ 1.      5.6397]
#  [ 1.      9.3102]
#  [ 1.      9.4536]
#  [ 1.      8.8254]
#  [ 1.      5.1793]
#  [ 1.     21.279 ]
#  [ 1.     14.908 ]
#  [ 1.     18.959 ]
#  [ 1.      7.2182]
#  [ 1.      8.2951]
#  [ 1.     10.236 ]
#  [ 1.      5.4994]
#  [ 1.     20.341 ]
#  [ 1.     10.136 ]
#  [ 1.      7.3345]
#  [ 1.      6.0062]
#  [ 1.      7.2259]
#  [ 1.      5.0269]
#  [ 1.      6.5479]
#  [ 1.      7.5386]
#  [ 1.      5.0365]
#  [ 1.     10.274 ]
#  [ 1.      5.1077]
#  [ 1.      5.7292]
#  [ 1.      5.1884]
#  [ 1.      6.3557]
#  [ 1.      9.7687]
#  [ 1.      6.5159]
#  [ 1.      8.5172]
#  [ 1.      9.1802]
#  [ 1.      6.002 ]
#  [ 1.      5.5204]
#  [ 1.      5.0594]
#  [ 1.      5.7077]
#  [ 1.      7.6366]
#  [ 1.      5.8707]
#  [ 1.      5.3054]
#  [ 1.      8.2934]
#  [ 1.     13.394 ]
#  [ 1.      5.4369]] [[17.592  ]
#  [ 9.1302 ]
#  [13.662  ]
#  [11.854  ]
#  [ 6.8233 ]
#  [11.886  ]
#  [ 4.3483 ]
#  [12.     ]
#  [ 6.5987 ]
#  [ 3.8166 ]
#  [ 3.2522 ]
#  [15.505  ]
#  [ 3.1551 ]
#  [ 7.2258 ]
#  [ 0.71618]
#  [ 3.5129 ]
#  [ 5.3048 ]
#  [ 0.56077]
#  [ 3.6518 ]
#  [ 5.3893 ]
#  [ 3.1386 ]
#  [21.767  ]
#  [ 4.263  ]
#  [ 5.1875 ]
#  [ 3.0825 ]
#  [22.638  ]
#  [13.501  ]
#  [ 7.0467 ]
#  [14.692  ]
#  [24.147  ]
#  [-1.22   ]
#  [ 5.9966 ]
#  [12.134  ]
#  [ 1.8495 ]
#  [ 6.5426 ]
#  [ 4.5623 ]
#  [ 4.1164 ]
#  [ 3.3928 ]
#  [10.117  ]
#  [ 5.4974 ]
#  [ 0.55657]
#  [ 3.9115 ]
#  [ 5.3854 ]
#  [ 2.4406 ]
#  [ 6.7318 ]
#  [ 1.0463 ]
#  [ 5.1337 ]
#  [ 1.844  ]
#  [ 8.0043 ]
#  [ 1.0179 ]
#  [ 6.7504 ]
#  [ 1.8396 ]
#  [ 4.2885 ]
#  [ 4.9981 ]
#  [ 1.4233 ]
#  [-1.4211 ]
#  [ 2.4756 ]
#  [ 4.6042 ]
#  [ 3.9624 ]
#  [ 5.4141 ]
#  [ 5.1694 ]
#  [-0.74279]
#  [17.929  ]
#  [12.054  ]
#  [17.054  ]
#  [ 4.8852 ]
#  [ 5.7442 ]
#  [ 7.7754 ]
#  [ 1.0173 ]
#  [20.992  ]
#  [ 6.6799 ]
#  [ 4.0259 ]
#  [ 1.2784 ]
#  [ 3.3411 ]
#  [-2.6807 ]
#  [ 0.29678]
#  [ 3.8845 ]
#  [ 5.7014 ]
#  [ 6.7526 ]
#  [ 2.0576 ]
#  [ 0.47953]
#  [ 0.20421]
#  [ 0.67861]
#  [ 7.5435 ]
#  [ 5.3436 ]
#  [ 4.2415 ]
#  [ 6.7981 ]
#  [ 0.92695]
#  [ 0.152  ]
#  [ 2.8214 ]
#  [ 1.8451 ]
#  [ 4.2959 ]
#  [ 7.2029 ]
#  [ 1.9869 ]
#  [ 0.14454]
#  [ 9.0551 ]
#  [ 0.61705]] [[0.]
#  [0.]]

# %% [markdown]
#  Gradient Descent
# ---

# %% [markdown]
# Minimize the cost function $J(\theta)$ by updating the below equation and repeat unitil convergence
#
# $\theta_j := \theta_j - \alpha \frac{1}{m} \sum_{i=1}^m (h_{\theta}(x^{(i)}) - y^{(i)})x_j^{(i)}$ (simultaneously update $\theta_j$ for all $j$).

# %%
def gradient_descent(x,y,theta,alpha,itr):
    m=len(y)
    cost=[]
    for i in range(itr):
        y_pred=x.dot(theta)
        error=np.dot(x.transpose(),(y_pred-y))
        theta-=alpha*1/m*error
        cost.append(cost_func(x,y,theta))
    return theta,cost

# %%
theta,cost=gradient_descent(x,y,theta,alpha=0.01,itr=2000)
print(theta)
# Out:
# [[-3.78806857]
#  [ 1.18221277]]

# %% [markdown]
#  Visualising the Cost Function $J(\theta)$
# ---

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
theta_0=np.linspace(-10,10,100)
theta_1=np.linspace(-1,4,100)

cost_values=np.zeros((len(theta_0),len(theta_1)))

for i in range(len(theta_0)):
    for j in range(len(theta_0)):
        t=np.array([theta_0[i],theta_1[j]])
        cost_values[i,j]=cost_func(x,y,t)

# %%
fig=plt.figure(figsize=(12,8))
ax=fig.gca(projection='3d')
surf=ax.plot_surface(theta_0,theta_1,cost_values,cmap='viridis')
fig.colorbar(surf,shrink=0.5,aspect=5)

plt.xlabel('\$Theta_0$')
plt.ylabel('\$Theta_1$')
ax.set_zlabel('$J(\Theta)$')
ax.view_init(30,330)
plt.show()

# %% [markdown]
# ### Task 7: Plotting the Convergence
# ---

# %% [markdown]
# Plot $J(\theta)$ against the number of iterations of gradient descent:

# %%
plt.plot(cost)
plt.xlabel('Iterations')
plt.ylabel('$J(\Theta)$')
plt.title('Plot against the number of iterations of gradient descent:')
# Out:
# Text(0.5, 1.0, 'Plot against the number of iterations of gradient descent:')

# %% [markdown]
# ### Task 8: Training Data with Linear Regression Fit
# ---

# %%
theta.shape
# Out:
# (2, 1)

# %%
theta=np.squeeze(theta)
sns.scatterplot(x='Population',y='Profit',data=data)

x_value=[x for x in range(5,25)]
y_value=[(x*theta[1]+theta[0]) for x in x_value]
sns.lineplot(x_value,y_value)

plt.xlabel("Population")
plt.ylabel("Profit")
plt.title('Linear Regression Fit')
# Out:
# Text(0.5, 1.0, 'Linear Regression Fit')

# %% [markdown]
# ### Task 9: Inference using the optimized $\theta$ values
# ---

# %% [markdown]
# $h_\theta(x) = \theta^Tx$

# %%
def predict(x,theta):
    y_pred=np.dot(theta.transpose(),x)
    return y_pred

# %%
str=float('6.74')
pred=predict(np.array([1,str]),theta)*10000
print(pred)
# Out:
# 41800.4552914161
